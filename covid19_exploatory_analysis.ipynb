# %% [markdown]
# <a href="https://colab.research.google.com/github/israelkingz/covid19-exploratory_analysis/blob/main/covid19_exploatory_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('covid_impact_edu_english.xlsx')

# %%
df.head()
# Out:
#                      Timestamp  ... Did the use of GIFs and unconventional options help you to enjoy and respond to this survey (1 being the least and 5 the highest)?
# 0  2020/07/19 3:53:07 PM GMT+1  ...                                                5.0
# 1  2020/07/19 3:54:23 PM GMT+1  ...                                                4.0
# 2  2020/07/19 3:57:35 PM GMT+1  ...                                                5.0
# 3  2020/07/19 4:01:39 PM GMT+1  ...                                                4.0
# 4  2020/07/19 4:06:13 PM GMT+1  ...                                                4.0
#
# [5 rows x 25 columns]

# %%
df = df.drop('Timestamp', axis=1)

# %%
df.head()
# Out:
#    Gender  ... Did the use of GIFs and unconventional options help you to enjoy and respond to this survey (1 being the least and 5 the highest)?
# 0    Male  ...                                                5.0
# 1  Female  ...                                                4.0
# 2    Male  ...                                                5.0
# 3    Male  ...                                                4.0
# 4  Female  ...                                                4.0
#
# [5 rows x 24 columns]

# %%
df['Gender'].value_counts()
# Out:
# Female               641
# Male                 625
# Prefer not to say     10
# Non-binary             1
# Name: Gender, dtype: int64

# %%
df['Name of school'].value_counts().head()
# Out:
# University of Ibadan            160
# University of Ibadan             80
# University of Nigeria Nsukka     21
# University of ibadan             21
# Obafemi Awolowo University       20
# Name: Name of school, dtype: int64

# %%
df.columns
# Out:
# Index(['Gender', 'Name of school', 'Course of study', 'I am a/an...student',
#        'Where did you stay during the semester before the pandemic?',
#        'If you are an undergraduate, what level are you in?',
#        'What have you been up to since the lockdown?',
#        'How do you feel about your future when you think about the effect of the pandemic on education in Nigeria?  ',
#        'Would you say COVID-19 has brought about any setback on education that may likely affect your future? ',
#        'On a scale of 1-5, how confident are you that your parents would have the source of income to continue funding your study in the face of the pandemic? ( 1=no confidence, 5= extreme confidence)',
#        'Will you still be able to live in the financial status of your student life that you had before the pandemic? ',
#        'Do you think your parents will allow you resume normal school activities as it were before the pandemic? ',
# ...

# %%
df['What have you been up to since the lockdown?'].value_counts().head() #top rank during the lockdown
# Out:
# Absolutely nothing!                   274
# Freelancing                           259
# Taking online courses                 256
# Continued my school classes online    140
# Community service/frontliner           91
# Name: What have you been up to since the lockdown?, dtype: int64

# %%
df['On a scale of 1-5, how confident are you that your parents would have the source of income to continue funding your study in the face of the pandemic? ( 1=no confidence, 5= extreme confidence)'].value_counts()
# Out:
# 3    384
# 5    323
# 4    298
# 1    145
# 2    127
# Name: On a scale of 1-5, how confident are you that your parents would have the source of income to continue funding your study in the face of the pandemic? ( 1=no confidence, 5= extreme confidence), dtype: int64

# %%
#The above shows that our students can move to virtual classes

# %%
df['Do you think your school can adapt to the current changes in the world to still bring you quality education? '].value_counts()
# Out:
# They'll try     462
# Definitely      311
# Maybe           217
# I don't know    148
# Hell no!        138
# Name: Do you think your school can adapt to the current changes in the world to still bring you quality education? , dtype: int64

# %%
#A good numbers of students believe that the school can adapt with the new changes in Nigeria

# %%
df['Will you still be able to live in the financial status of your student life that you had before the pandemic? '].value_counts()
# Out:
# Maybe           328
# Definitely!     308
# I'll try        290
# I don't know    213
# Nope!           138
# Name: Will you still be able to live in the financial status of your student life that you had before the pandemic? , dtype: int64

# %%
df['Where did you stay during the semester before the pandemic?'].value_counts()
# Out:
# School hostel                    402
# With my family                   276
# Self-contain apartment           258
# Private hostel outside school    229
# Private hostel within school     107
# Name: Where did you stay during the semester before the pandemic?, dtype: int64

# %%
df['If you are an undergraduate, what level are you in?'].value_counts()
# Out:
# 300.0    325
# 400.0    293
# 200.0    200
# 500.0    163
# 100.0     82
# 600.0     17
# Name: If you are an undergraduate, what level are you in?, dtype: int64

# %%
df['Would you say COVID-19 has brought about any setback on education that may likely affect your future? '].value_counts()
# Out:
# Yes!            557
# A little        262
# Nope            210
# Maybe           190
# I don't know     58
# Name: Would you say COVID-19 has brought about any setback on education that may likely affect your future? , dtype: int64

# %%
df['Will you still be able to live in the financial status of your student life that you had before the pandemic? '].value_counts()
# Out:
# Maybe           328
# Definitely!     308
# I'll try        290
# I don't know    213
# Nope!           138
# Name: Will you still be able to live in the financial status of your student life that you had before the pandemic? , dtype: int64

# %%
df['What extent do you think your parent will go to ensure your safety in school in the face of COVID19? (With the minimum extent being 1 and maximum extent being 5) '].value_counts()
# Out:
# 5    613
# 4    301
# 3    233
# 1     67
# 2     63
# Name: What extent do you think your parent will go to ensure your safety in school in the face of COVID19? (With the minimum extent being 1 and maximum extent being 5) , dtype: int64

# %%
df['I am a/an...student'].value_counts()
# Out:
# Undergraduate    1076
# Postgraduate      167
# Doctoral           30
# Post-doctoral       4
# Name: I am a/an...student, dtype: int64

# %%
df['What will be your likely reaction if you heard normal school activities are to resume immediately? '].value_counts()
# Out:
# Excited        560
# Indifferent    252
# Worried        249
# Shocked        180
# Angry           36
# Name: What will be your likely reaction if you heard normal school activities are to resume immediately? , dtype: int64

# %%
df['If school resumes normally, will you live and act in school like you used to? '].value_counts()
# Out:
# When I get to that bridge, I'll cross it    475
# Definitely                                  344
# Hell no!                                    213
# Maybe                                       164
# I don't know                                 81
# Name: If school resumes normally, will you live and act in school like you used to? , dtype: int64

# %%
df['If you must resume school normally, which of the following will you likely bring back with you? '].value_counts().head()
# Out:
# Nothing, just my awesome self                                             342
# Nose masks to match every occasion and outfit;A shipload of sanitizers    272
# Nose masks to match every occasion and outfit                             234
# A shipload of sanitizers                                                  178
# New wardrobe                                                               66
# Name: If you must resume school normally, which of the following will you likely bring back with you? , dtype: int64

# %%
df['If you lived in a school hostel before the pandemic, would you change accommodation to a private apartment?'].value_counts()
# Out:
# Hell no!                        312
# I haven't given it a thought    264
# Definitely!                     240
# Maybe                           171
# I don't know                    135
# Name: If you lived in a school hostel before the pandemic, would you change accommodation to a private apartment?, dtype: int64

# %%
df['Do you think your school can effectively implement the COVID-19 safety measures to keep you safe? '].value_counts()
# Out:
# They'll try     431
# Definitely      292
# Hell no!        232
# Maybe           181
# I don't know    140
# Name: Do you think your school can effectively implement the COVID-19 safety measures to keep you safe? , dtype: int64

# %%
df ['Does your school have what it takes to ensure social distancing within its current hostel set up?'].value_counts()
# Out:
# Hell no!        536
# They'll try     243
# Definitely      173
# I don't know    167
# Maybe           148
# Name: Does your school have what it takes to ensure social distancing within its current hostel set up?, dtype: int64

# %%
df['Do you think your school can adapt to the current changes in the world to still bring you quality education? '].value_counts()
# Out:
# They'll try     462
# Definitely      311
# Maybe           217
# I don't know    148
# Hell no!        138
# Name: Do you think your school can adapt to the current changes in the world to still bring you quality education? , dtype: int64

# %%
df['Do you think your lecturers will take precautionary measures to keep you safe from COVID-19? '].value_counts()
# Out:
# They'll try     442
# Definitely      396
# Maybe           208
# I don't know    137
# Hell no!         93
# Name: Do you think your lecturers will take precautionary measures to keep you safe from COVID-19? , dtype: int64

# %%
df['Do you think your lecturers are equipped to deliver quality education in the face of the pandemic e.g. adopting online teaching etc? '].value_counts()
# Out:
# They'll figure something out    364
# Definitely                      304
# Hell no!                        253
# Maybe                           183
# I don't know                    172
# Name: Do you think your lecturers are equipped to deliver quality education in the face of the pandemic e.g. adopting online teaching etc? , dtype: int64

# %%
df['Do you think your lecturers are willing to go the extra mile to deliver quality education in the face of the pandemic? '].value_counts()
# Out:
# They'll make some effort    435
# Definitely                  282
# Maybe                       218
# I don't know                183
# Hell no!                    158
# Name: Do you think your lecturers are willing to go the extra mile to deliver quality education in the face of the pandemic? , dtype: int64

# %%
df['Did the use of GIFs and unconventional options help you to enjoy and respond to this survey (1 being the least and 5 the highest)? '].value_counts()
# Out:
# 5.0    587
# 4.0    339
# 3.0    239
# 1.0     61
# 2.0     50
# Name: Did the use of GIFs and unconventional options help you to enjoy and respond to this survey (1 being the least and 5 the highest)? , dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['Course of study'].value_counts().head(10)
# Out:
# Computer Science                   53
# Computer science                   32
# Pharmacy                           30
# Computer science                   28
# Computer Science                   26
# Library and information science    20
# Pharmacy                           20
# Mechanical Engineering             16
# Law                                16
# Nursing                            16
# Name: Course of study, dtype: int64

# %%
df[df['Course of study']=='Computer Science'].value_counts()
# Out:
# Gender  Name of school                                            Course of study   I am a/an...student  Where did you stay during the semester before the pandemic?  If you are an undergraduate, what level are you in?  What have you been up to since the lockdown?                                                       How do you feel about your future when you think about the effect of the pandemic on education in Nigeria?    Would you say COVID-19 has brought about any setback on education that may likely affect your future?   On a scale of 1-5, how confident are you that your parents would have the source of income to continue funding your study in the face of the pandemic? ( 1=no confidence, 5= extreme confidence)  Will you still be able to live in the financial status of your student life that you had before the pandemic?   Do you think your parents will allow you resume normal school activities as it were before the pandemic?   What extent do you think your parent will go to ensur
# ...

# %%
df.shape
# Out:
# (1277, 24)

# %%
df.columns
# Out:
# Index(['Gender', 'Name of school', 'Course of study', 'I am a/an...student',
#        'Where did you stay during the semester before the pandemic?',
#        'If you are an undergraduate, what level are you in?',
#        'What have you been up to since the lockdown?',
#        'How do you feel about your future when you think about the effect of the pandemic on education in Nigeria?  ',
#        'Would you say COVID-19 has brought about any setback on education that may likely affect your future? ',
#        'On a scale of 1-5, how confident are you that your parents would have the source of income to continue funding your study in the face of the pandemic? ( 1=no confidence, 5= extreme confidence)',
#        'Will you still be able to live in the financial status of your student life that you had before the pandemic? ',
#        'Do you think your parents will allow you resume normal school activities as it were before the pandemic? ',
# ...

# %%
df.groupby('I am a/an...student').mean()['On a scale of 1-5, how confident are you that your parents would have the source of income to continue funding your study in the face of the pandemic? ( 1=no confidence, 5= extreme confidence)']
# Out:
# I am a/an...student
# Doctoral         3.400000
# Post-doctoral    2.750000
# Postgraduate     3.185629
# Undergraduate    3.450743
# Name: On a scale of 1-5, how confident are you that your parents would have the source of income to continue funding your study in the face of the pandemic? ( 1=no confidence, 5= extreme confidence), dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1277 entries, 0 to 1276
# Data columns (total 24 columns):
#  #   Column                                                                                                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                            --------------  -----
#  0   Gender                                                                                                                                                                                            1277 non-null   object
# ...

# %%
sns.countplot(y='Do you think your school can adapt to the current changes in the world to still bring you quality education? ',hue='Gender',data=df)#Division to be made a dummy

# %%
sns.countplot(y='Do you think your lecturers are equipped to deliver quality education in the face of the pandemic e.g. adopting online teaching etc? ',hue='Gender',data=df)

# %%
sns.countplot(y='What have you been up to since the lockdown?',hue='If you are an undergraduate, what level are you in?',data=df)

# %%
sns.countplot(y='On a scale of 1-5, how confident are you that your parents would have the source of income to continue funding your study in the face of the pandemic? ( 1=no confidence, 5= extreme confidence)',hue='If you are an undergraduate, what level are you in?',data=df)

# %%
sns.countplot(y='On a scale of 1-5, how confident are you that your parents would have the source of income to continue funding your study in the face of the pandemic? ( 1=no confidence, 5= extreme confidence)',hue='I am a/an...student',data=df)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df.columns
# Out:
# Index(['Gender', 'Name of school', 'Course of study', 'I am a/an...student',
#        'Where did you stay during the semester before the pandemic?',
#        'If you are an undergraduate, what level are you in?',
#        'What have you been up to since the lockdown?',
#        'How do you feel about your future when you think about the effect of the pandemic on education in Nigeria?  ',
#        'Would you say COVID-19 has brought about any setback on education that may likely affect your future? ',
#        'On a scale of 1-5, how confident are you that your parents would have the source of income to continue funding your study in the face of the pandemic? ( 1=no confidence, 5= extreme confidence)',
#        'Will you still be able to live in the financial status of your student life that you had before the pandemic? ',
#        'Do you think your parents will allow you resume normal school activities as it were before the pandemic? ',
# ...

# %%
df['Gender'].hist()

# %%
plt.style.use('bmh')
df['If you are an undergraduate, what level are you in?'].hist()

# %%
df.plot.area(alpha=0.7)

# %%
df.plot.bar()
